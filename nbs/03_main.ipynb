# %% [markdown]
# # Main
#
# > Main file for plotting graphs

# %%
#| default_exp main

# %%
#| hide
from nbdev.showdoc import *

# %%
#| hide
import nbdev; nbdev.nbdev_export()

# %%
#| export
import matplotlib.pyplot as plt
import numpy as np
import math
from nbdev_test_project.graph import Graph as Graph
from nbdev_test_project.plot import SimplePlot as MyPlot

# %%
#| export
X = np.arange(0, math.pi * 2, 0.001)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.tan(X)

# %%
plot = MyPlot()
graph = Graph(X, Y1, "Sine")

# %%
plot.add_graph(graph)
plot.set_plot(plt)

# %%
plot??
# Out:
# Type:        SimplePlot
# String form: <nbdev_test_project.plot.SimplePlot object at 0x7fef42edfbb0>
# File:        ~/PythonProjects/nbdev-test-project/nbs/nbdev_test_project/plot.py
# Source:
# class SimplePlot:
#     def __init__(self):
#         self.graph_list = []
#     def set_plot(self, plot):
#         self.plt = plot
#     def add_graph(self, graph):
#         self.graph_list.append(graph)
#     def plot_first_graph(self):
#         if len(self.graph_list) != 0:
#             self.plt.suptitle(self.graph_list[0].get_name())
#             self.plt.plot(self.graph_list[0].get_x(),self.graph_list[0].get_y())

# %%
len(plot.graph_list)
# Out:
# 1

# %%
plot
plot.plot_first_graph()
